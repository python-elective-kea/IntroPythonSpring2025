# %%
#!pip install numpy
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

a1 = np.array([1, 2, 3, 4, 5])
a2 = np.arange(1, 10, 0.5)
a3 = np.ones(10)

a4 = np.linspace(0, 10, 200)

# %%
a1 * 2

def f(x):
    return x^2 + 2*x +4


y = f(a1)

y
# Out:
# array([ 9,  8, 15, 10, 21])

# %%
a1
# Out:
# array([100,   2,   3,   4,   5])

# %% [markdown]
# 1[]('../../../assets/flower.png)

# %% [markdown]
# ## Flower imgae

# %%
flower = plt.imread('/Users/clbo/Tresors/KEA/python/repos/IntroPythonSpring2025/assets/flower.png')
copy = flower.copy()

copy[1, :, 1] = .2

# %%
copy
# Out:
# array([[[0.3254902 , 0.48235294, 0.78431374, 1.        ],
#         [0.3254902 , 0.48235294, 0.78431374, 1.        ],
#         [0.3254902 , 0.47843137, 0.78431374, 1.        ],
#         ...,
#         [0.39215687, 0.4745098 , 0.26666668, 1.        ],
#         [0.39607844, 0.47843137, 0.2627451 , 1.        ],
#         [0.39607844, 0.4862745 , 0.2627451 , 1.        ]],
#
#        [[0.32941177, 0.2       , 0.79607844, 1.        ],
#         [0.32941177, 0.2       , 0.79607844, 1.        ],
#         [0.32941177, 0.2       , 0.79607844, 1.        ],
#         ...,
#         [0.39607844, 0.2       , 0.2627451 , 1.        ],
#         [0.4       , 0.2       , 0.2627451 , 1.        ],
#         [0.40392157, 0.2       , 0.2627451 , 1.        ]],
#
#        [[0.32941177, 0.49019608, 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         ...,
# ...

# %%
plt.imshow(copy)

# %%
plt.imshow(flower)

# %% [markdown]
# ## Matplotlib

# %%
x = np.array([1, 2, 3, 4])
y = [10, 12, 14, 16]

plt.bar(x, y)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
x = np.linspace(0, 200, 400)

y1 = x
y2 = x/2
y3 = np.log2(x)

plt.plot(x, y1, label='n', color='red')
plt.plot(x, y2, label='n/2', color='blue')
plt.plot(x, y3, label='log2(n)', color='black')

plt.title('Big o notation')
plt.legend()

plt.ylim(0,12)
plt.xlim(0,200)


plt.xlabel('Input size(n)')
plt.ylabel('Time complexity')

plt.grid(True)
plt.show()
# Out:
# /var/folders/2t/3plkrfzx0pbf0752vdv6lspw0000gn/T/ipykernel_25478/3637970578.py:5: RuntimeWarning: divide by zero encountered in log2
#   y3 = np.log2(x)

# %%
x
# Out:
# array([  0.        ,   0.50125313,   1.00250627,   1.5037594 ,
#          2.00501253,   2.50626566,   3.0075188 ,   3.50877193,
#          4.01002506,   4.5112782 ,   5.01253133,   5.51378446,
#          6.01503759,   6.51629073,   7.01754386,   7.51879699,
#          8.02005013,   8.52130326,   9.02255639,   9.52380952,
#         10.02506266,  10.52631579,  11.02756892,  11.52882206,
#         12.03007519,  12.53132832,  13.03258145,  13.53383459,
#         14.03508772,  14.53634085,  15.03759398,  15.53884712,
#         16.04010025,  16.54135338,  17.04260652,  17.54385965,
#         18.04511278,  18.54636591,  19.04761905,  19.54887218,
#         20.05012531,  20.55137845,  21.05263158,  21.55388471,
#         22.05513784,  22.55639098,  23.05764411,  23.55889724,
#         24.06015038,  24.56140351,  25.06265664,  25.56390977,
#         26.06516291,  26.56641604,  27.06766917,  27.56892231,
#         28.07017544,  28.57142857,  29.0726817 ,  29.57393484,
# ...

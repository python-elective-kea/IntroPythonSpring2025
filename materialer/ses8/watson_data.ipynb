# %% [markdown]
# # Watson data

# %% [markdown]
# Generate the data and write it to a file

# %%
import random
import string

def generate_watson_test_data(num_tuples=10, tuple_length=4):
    data = []
    for _ in range(num_tuples):
        inner_tuple = tuple(
            (
                random.choice(string.ascii_uppercase), random.randint(1, 10)) if random.choice([True, False]
            ) 
            else (
                    random.randint(1, 10), random.choice(string.ascii_uppercase)
                )
            for _ in range(tuple_length)
        )
        data.append(inner_tuple)
    return data

# Generate sample data
watson_test_data = generate_watson_test_data(108, 4)

with open('watson_data.py', 'w') as f:
    f.write(f'{watson_test_data}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 22
#      19 # Generate sample data
#      20 watson_test_data = generate_watson_test_data(108, 4)
# ---> 22 with open('watson_data.py', 'w') as f:
#      23     f.write(f'{watson_test_data}')
#
# File ~/Tresors/KEA/python/repos/IntroPythonSpring2025/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'watson_data.py'

# %%
#import watson_data as wd 

import requests
res = requests.get('https://raw.githubusercontent.com/python-elective-kea/IntroPythonSpring2025/refs/heads/main/materialer/ses8/watson_data.py')
text = res.text
data = eval(text)
data


# hvor mange sæt kort er der i filen?
#len(wd.watson_data)
# Out:
# [((7, 'R'), ('C', 8), ('Z', 10), ('B', 10)),
#  (('Q', 3), (4, 'J'), (1, 'M'), (9, 'T')),
#  (('S', 8), ('Z', 8), ('K', 7), ('G', 3)),
#  ((10, 'Q'), (2, 'X'), (5, 'L'), (8, 'E')),
#  (('I', 8), (9, 'A'), ('K', 1), (6, 'Y')),
#  ((3, 'K'), (4, 'F'), (5, 'R'), (8, 'Y')),
#  (('P', 9), (5, 'X'), (7, 'O'), ('N', 6)),
#  (('C', 5), (5, 'C'), (2, 'T'), (7, 'O')),
#  (('X', 2), ('A', 4), ('I', 7), (1, 'V')),
#  ((10, 'U'), (3, 'M'), (10, 'I'), (8, 'C')),
#  (('B', 1), (8, 'I'), ('E', 9), ('P', 9)),
#  ((6, 'K'), ('Z', 10), ('R', 1), (6, 'O')),
#  ((6, 'R'), ('I', 5), (3, 'U'), (2, 'T')),
#  (('M', 5), (9, 'S'), (3, 'O'), (7, 'Y')),
#  ((8, 'H'), ('L', 6), (3, 'E'), (10, 'F')),
#  (('M', 7), ('X', 6), (8, 'W'), (10, 'I')),
#  ((6, 'Z'), (6, 'W'), (6, 'R'), (10, 'K')),
#  ((7, 'I'), (5, 'J'), (8, 'T'), ('V', 3)),
#  ((9, 'E'), ('S', 4), ('P', 10), (6, 'Q')),
#  (('C', 1), (1, 'Z'), ('V', 4), (7, 'F')),
#  (('X', 9), (4, 'K'), ('U', 8), (7, 'U')),
#  ((1, 'N'), (7, 'W'), (7, 'V'), ('D', 7)),
#  (('P', 4), ('J', 7), ('A', 9), (1, 'Q')),
#  ((8, 'R'), ('T', 8), ('T', 10), ('X', 9)),
#  ((5, 'D'), ('W', 7), ('Q', 1), (1, 'E')),
#  (('B', 4), (9, 'R'), ('G', 2), (7, 'V')),
#  (('D', 4), ('D', 4), (3, 'H'), ('T', 3)),
#  (('G', 4), ('Z', 10), (6, 'E'), (4, 'V')),
#  (('T', 8), ('B', 2), ('P', 1), ('B', 6)),
#  ((9, 'G'), (1, 'U'), ('B', 6), ('V', 1)),
#  (('E', 5), ('L', 5), (1, 'I'), (2, 'N')),
#  ((4, 'B'), (6, 'O'), (7, 'Q'), ('Q', 1)),
#  (('N', 6), ('O', 4), (7, 'T'), ('V', 5)),
#  ((8, 'X'), ('U', 8), (10, 'A'), (3, 'U')),
#  (('N', 10), (9, 'C'), (7, 'G'), ('G', 3)),
#  ((10, 'I'), (6, 'N'), (1, 'I'), (10, 'V')),
#  (('O', 4), (2, 'X'), (1, 'D'), (2, 'M')),
#  ((4, 'U'), (3, 'W'), (8, 'U'), (1, 'M')),
#  ((1, 'L'), (6, 'E'), (2, 'I'), (9, 'J')),
#  (('K', 6), ('T', 10), ('D', 3), ('V', 9)),
#  (('K', 5), (4, 'B'), (9, 'P'), ('N', 7)),
#  ((10, 'E'), (8, 'D'), ('D', 5), ('C', 2)),
#  ((7, 'J'), (10, 'V'), (2, 'C'), ('C', 9)),
#  ((8, 'C'), ('D', 6), (10, 'V'), (1, 'P')),
#  ((5, 'D'), (10, 'F'), (5, 'N'), ('U', 9)),
#  (('G', 8), (8, 'O'), ('J', 8), ('A', 4)),
#  ((5, 'I'), (8, 'Z'), (5, 'D'), ('B', 4)),
#  (('Y', 7), (3, 'R'), (9, 'S'), (1, 'M')),
#  ((1, 'G'), (2, 'F'), (7, 'T'), (1, 'E')),
#  (('Y', 6), ('F', 9), (2, 'K'), ('W', 7)),
#  (('S', 5), ('K', 8), ('S', 3), ('U', 1)),
#  (('U', 9), ('V', 6), ('D', 7), (5, 'K')),
#  (('A', 9), ('D', 7), ('F', 8), (7, 'Q')),
#  ((5, 'C'), (2, 'C'), (8, 'T'), ('T', 10)),
#  ((5, 'W'), ('J', 1), ('N', 5), (5, 'A')),
#  (('M', 8), (9, 'J'), ('R', 2), ('R', 8)),
#  (('P', 7), (5, 'X'), (4, 'L'), (8, 'P')),
#  (('E', 7), (5, 'G'), ('L', 6), (2, 'C')),
#  (('E', 6), (7, 'U'), ('M', 3), (8, 'O')),
#  (('C', 7), ('N', 9), (10, 'B'), ('Y', 6)),
#  (('W', 10), ('I', 8), (10, 'A'), (8, 'Q')),
#  (('A', 2), ('B', 7), ('Y', 10), ('O', 10)),
#  ((9, 'B'), ('Y', 4), (8, 'X'), (5, 'A')),
#  ((5, 'X'), ('F', 8), (9, 'K'), (5, 'N')),
#  (('L', 8), (3, 'U'), ('P', 10), ('P', 1)),
#  (('W', 2), ('V', 3), (8, 'B'), ('Q', 6)),
#  (('J', 4), (6, 'C'), ('Z', 4), ('H', 5)),
#  ((6, 'V'), (9, 'W'), ('L', 10), (8, 'I')),
#  (('D', 10), (8, 'E'), ('N', 4), (2, 'C')),
#  ((8, 'S'), (9, 'B'), ('I', 6), ('F', 7)),
#  ((10, 'L'), (6, 'L'), (10, 'F'), ('F', 2)),
#  (('E', 5), (1, 'Z'), ('S', 6), ('A', 8)),
#  (('A', 8), ('S', 3), ('A', 1), ('A', 9)),
#  (('N', 10), (10, 'X'), ('Q', 9), (1, 'R')),
#  ((3, 'U'), (7, 'U'), (1, 'B'), (2, 'B')),
#  ((7, 'B'), (2, 'C'), ('Z', 8), (5, 'U')),
#  ((6, 'Z'), ('H', 6), (5, 'G'), (6, 'A')),
#  ((6, 'Y'), ('T', 8), ('F', 2), ('Q', 3)),
#  ((5, 'J'), ('I', 4), ('H', 10), (8, 'I')),
#  (('V', 8), ('N', 7), (9, 'I'), ('K', 7)),
#  ((10, 'O'), ('R', 7), (2, 'D'), (9, 'H')),
#  (('A', 2), (7, 'R'), ('A', 2), ('L', 7)),
#  (('Z', 2), ('M', 10), ('C', 8), (4, 'H')),
#  (('V', 7), (3, 'I'), (5, 'O'), (1, 'V')),
#  (('D', 8), (5, 'I'), ('X', 8), ('K', 8)),
#  (('U', 3), ('Q', 10), ('X', 4), (4, 'V')),
#  (('L', 10), (6, 'C'), ('K', 1), ('V', 10)),
#  (('I', 6), (8, 'W'), (2, 'S'), ('Z', 1)),
#  ((5, 'Y'), ('X', 2), (3, 'P'), ('C', 2)),
#  (('D', 10), (7, 'G'), (7, 'E'), ('J', 9)),
#  ((4, 'N'), (6, 'G'), ('G', 10), (9, 'L')),
#  (('N', 4), ('K', 9), ('B', 7), (1, 'S')),
#  (('U', 1), (7, 'U'), ('Z', 10), ('K', 3)),
#  ((7, 'N'), ('D', 9), ('B', 8), (9, 'H')),
#  ((2, 'V'), ('R', 4), (5, 'X'), ('U', 1)),
#  ((1, 'G'), ('V', 5), ('L', 7), ('D', 3)),
#  ((2, 'C'), (3, 'W'), (6, 'U'), (2, 'M')),
#  (('L', 9), ('H', 2), (2, 'K'), (6, 'S')),
#  (('K', 1), (3, 'J'), ('T', 1), (8, 'U')),
#  (('E', 7), ('X', 8), (8, 'C'), (3, 'L')),
#  ((3, 'R'), ('R', 8), ('L', 5), ('R', 9)),
#  ((1, 'T'), (1, 'T'), (3, 'T'), ('G', 6)),
#  ((9, 'N'), ('T', 5), ('O', 6), ('H', 7)),
#  (('Q', 5), (2, 'M'), ('M', 7), ('I', 8)),
#  ((10, 'F'), (7, 'H'), (2, 'D'), (1, 'W')),
#  (('K', 8), ('H', 2), ('Z', 10), ('S', 4)),
#  ((1, 'G'), ('U', 9), (3, 'D'), ('O', 1)),
#  (('E', 9), (3, 'Q'), ('G', 5), ('Z', 7))]

# %%
len(data)
# Out:
# 108

# %%
# I hvor mange af sættene der er brug for at vende et kort?
res = []
for i in data:
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            res.append(j)
            break
        
len(res), res
# Out:
# (88,
#  [(7, 'R'),
#   (1, 'M'),
#   (5, 'L'),
#   ('I', 8),
#   (3, 'K'),
#   (5, 'X'),
#   (5, 'C'),
#   ('A', 4),
#   (3, 'M'),
#   ('E', 9),
#   ('I', 5),
#   (9, 'S'),
#   (3, 'E'),
#   (7, 'I'),
#   (9, 'E'),
#   (1, 'Z'),
#   ('U', 8),
#   (1, 'N'),
#   ('A', 9),
#   (5, 'D'),
#   (9, 'R'),
#   (3, 'H'),
#   (9, 'G'),
#   ('E', 5),
#   (7, 'Q'),
#   ('O', 4),
#   ('U', 8),
#   (9, 'C'),
#   (1, 'I'),
#   ('O', 4),
#   (3, 'W'),
#   (1, 'L'),
#   (9, 'P'),
#   (7, 'J'),
#   (1, 'P'),
#   (5, 'D'),
#   ('A', 4),
#   (5, 'I'),
#   (3, 'R'),
#   (1, 'G'),
#   ('U', 1),
#   ('U', 9),
#   ('A', 9),
#   (5, 'C'),
#   (5, 'W'),
#   (9, 'J'),
#   (5, 'X'),
#   ('E', 7),
#   ('E', 6),
#   ('I', 8),
#   ('A', 2),
#   (9, 'B'),
#   (5, 'X'),
#   (3, 'U'),
#   (9, 'W'),
#   (9, 'B'),
#   ('E', 5),
#   ('A', 8),
#   (1, 'R'),
#   (3, 'U'),
#   (7, 'B'),
#   (5, 'G'),
#   (5, 'J'),
#   (9, 'I'),
#   (9, 'H'),
#   ('A', 2),
#   (3, 'I'),
#   (5, 'I'),
#   ('U', 3),
#   ('I', 6),
#   (5, 'Y'),
#   (7, 'G'),
#   (9, 'L'),
#   (1, 'S'),
#   ('U', 1),
#   (7, 'N'),
#   (5, 'X'),
#   (1, 'G'),
#   (3, 'W'),
#   (3, 'J'),
#   ('E', 7),
#   (3, 'R'),
#   (1, 'T'),
#   (9, 'N'),
#   ('I', 8),
#   (7, 'H'),
#   (1, 'G'),
#   ('E', 9)])

# %%
# I hvor man af sættene der er brug for at vende 2 kort?
res = []
for i in data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 2:
                res.append('x')
len(res), res

#['x' for i in wd.watson_data for j in i if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2)]
# Out:
# (60,
#  ['x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x'])

# %%
# I hvor man af sættene der er brug for at vende 3 kort?
res = []
for i in data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 3:
                res.append(i)
len(res), res
# Out:
# (13,
#  [((3, 'C'), (7, 'O'), (9, 'L'), (2, 'W')),
#   ((10, 'T'), (5, 'B'), (3, 'A'), ('A', 3)),
#   ((9, 'O'), (1, 'L'), ('D', 8), (5, 'H')),
#   ((10, 'Y'), (3, 'I'), (3, 'A'), (3, 'T')),
#   ((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B')),
#   ((5, 'D'), (10, 'B'), (7, 'G'), (5, 'E')),
#   (('Z', 5), (7, 'P'), (9, 'B'), ('I', 5)),
#   ((7, 'C'), (7, 'D'), ('I', 5), ('W', 3)),
#   (('L', 9), ('E', 5), (7, 'S'), (3, 'F')),
#   (('C', 3), (3, 'X'), (5, 'T'), (7, 'O')),
#   ((5, 'D'), (7, 'I'), (1, 'V'), ('G', 7)),
#   ((7, 'G'), ('M', 2), ('I', 7), (3, 'P')),
#   (('A', 8), (8, 'W'), (1, 'Z'), (5, 'E'))])

# %%
# I hvor man af sættene der er brug for at vende 4 kort?
res = []
for i in data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 4:
                res.append(i)
len(res), res
# Out:
# (1, [((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B'))])

# %%
# Hvor mange set vil fejle testen?
res = []
for i in data:
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] and j[1] not in [2,4,6,8] or j[0] in range(1,10,2) and j[1] in ['A', 'E', 'I', 'O', 'U']: 
            res.append(j)
len(res), res
# Out:
# (4, [(7, 'U'), (9, 'I'), (5, 'U'), (1, 'E')])

# %% [markdown]
# Flatten the file

# %%
[tup for cards in data for card in cards for tup in card]
# Out:
# [7,
#  'R',
#  'C',
#  8,
#  'Z',
#  10,
#  'B',
#  10,
#  'Q',
#  3,
#  4,
#  'J',
#  1,
#  'M',
#  9,
#  'T',
#  'S',
#  8,
#  'Z',
#  8,
#  'K',
#  7,
#  'G',
#  3,
#  10,
#  'Q',
#  2,
#  'X',
#  5,
#  'L',
#  8,
#  'E',
#  'I',
#  8,
#  9,
#  'A',
#  'K',
#  1,
#  6,
#  'Y',
#  3,
#  'K',
#  4,
#  'F',
#  5,
#  'R',
#  8,
#  'Y',
#  'P',
#  9,
#  5,
#  'X',
#  7,
#  'O',
#  'N',
#  6,
#  'C',
#  5,
#  5,
#  'C',
#  2,
#  'T',
#  7,
#  'O',
#  'X',
#  2,
#  'A',
#  4,
#  'I',
#  7,
#  1,
#  'V',
#  10,
#  'U',
#  3,
#  'M',
#  10,
#  'I',
#  8,
#  'C',
#  'B',
#  1,
#  8,
#  'I',
#  'E',
#  9,
#  'P',
#  9,
#  6,
#  'K',
#  'Z',
#  10,
#  'R',
#  1,
#  6,
#  'O',
#  6,
#  'R',
#  'I',
#  5,
#  3,
#  'U',
#  2,
#  'T',
#  'M',
#  5,
#  9,
#  'S',
#  3,
#  'O',
#  7,
#  'Y',
#  8,
#  'H',
#  'L',
#  6,
#  3,
#  'E',
#  10,
#  'F',
#  'M',
#  7,
#  'X',
#  6,
#  8,
#  'W',
#  10,
#  'I',
#  6,
#  'Z',
#  6,
#  'W',
#  6,
#  'R',
#  10,
#  'K',
#  7,
#  'I',
#  5,
#  'J',
#  8,
#  'T',
#  'V',
#  3,
#  9,
#  'E',
#  'S',
#  4,
#  'P',
#  10,
#  6,
#  'Q',
#  'C',
#  1,
#  1,
#  'Z',
#  'V',
#  4,
#  7,
#  'F',
#  'X',
#  9,
#  4,
#  'K',
#  'U',
#  8,
#  7,
#  'U',
#  1,
#  'N',
#  7,
#  'W',
#  7,
#  'V',
#  'D',
#  7,
#  'P',
#  4,
#  'J',
#  7,
#  'A',
#  9,
#  1,
#  'Q',
#  8,
#  'R',
#  'T',
#  8,
#  'T',
#  10,
#  'X',
#  9,
#  5,
#  'D',
#  'W',
#  7,
#  'Q',
#  1,
#  1,
#  'E',
#  'B',
#  4,
#  9,
#  'R',
#  'G',
#  2,
#  7,
#  'V',
#  'D',
#  4,
#  'D',
#  4,
#  3,
#  'H',
#  'T',
#  3,
#  'G',
#  4,
#  'Z',
#  10,
#  6,
#  'E',
#  4,
#  'V',
#  'T',
#  8,
#  'B',
#  2,
#  'P',
#  1,
#  'B',
#  6,
#  9,
#  'G',
#  1,
#  'U',
#  'B',
#  6,
#  'V',
#  1,
#  'E',
#  5,
#  'L',
#  5,
#  1,
#  'I',
#  2,
#  'N',
#  4,
#  'B',
#  6,
#  'O',
#  7,
#  'Q',
#  'Q',
#  1,
#  'N',
#  6,
#  'O',
#  4,
#  7,
#  'T',
#  'V',
#  5,
#  8,
#  'X',
#  'U',
#  8,
#  10,
#  'A',
#  3,
#  'U',
#  'N',
#  10,
#  9,
#  'C',
#  7,
#  'G',
#  'G',
#  3,
#  10,
#  'I',
#  6,
#  'N',
#  1,
#  'I',
#  10,
#  'V',
#  'O',
#  4,
#  2,
#  'X',
#  1,
#  'D',
#  2,
#  'M',
#  4,
#  'U',
#  3,
#  'W',
#  8,
#  'U',
#  1,
#  'M',
#  1,
#  'L',
#  6,
#  'E',
#  2,
#  'I',
#  9,
#  'J',
#  'K',
#  6,
#  'T',
#  10,
#  'D',
#  3,
#  'V',
#  9,
#  'K',
#  5,
#  4,
#  'B',
#  9,
#  'P',
#  'N',
#  7,
#  10,
#  'E',
#  8,
#  'D',
#  'D',
#  5,
#  'C',
#  2,
#  7,
#  'J',
#  10,
#  'V',
#  2,
#  'C',
#  'C',
#  9,
#  8,
#  'C',
#  'D',
#  6,
#  10,
#  'V',
#  1,
#  'P',
#  5,
#  'D',
#  10,
#  'F',
#  5,
#  'N',
#  'U',
#  9,
#  'G',
#  8,
#  8,
#  'O',
#  'J',
#  8,
#  'A',
#  4,
#  5,
#  'I',
#  8,
#  'Z',
#  5,
#  'D',
#  'B',
#  4,
#  'Y',
#  7,
#  3,
#  'R',
#  9,
#  'S',
#  1,
#  'M',
#  1,
#  'G',
#  2,
#  'F',
#  7,
#  'T',
#  1,
#  'E',
#  'Y',
#  6,
#  'F',
#  9,
#  2,
#  'K',
#  'W',
#  7,
#  'S',
#  5,
#  'K',
#  8,
#  'S',
#  3,
#  'U',
#  1,
#  'U',
#  9,
#  'V',
#  6,
#  'D',
#  7,
#  5,
#  'K',
#  'A',
#  9,
#  'D',
#  7,
#  'F',
#  8,
#  7,
#  'Q',
#  5,
#  'C',
#  2,
#  'C',
#  8,
#  'T',
#  'T',
#  10,
#  5,
#  'W',
#  'J',
#  1,
#  'N',
#  5,
#  5,
#  'A',
#  'M',
#  8,
#  9,
#  'J',
#  'R',
#  2,
#  'R',
#  8,
#  'P',
#  7,
#  5,
#  'X',
#  4,
#  'L',
#  8,
#  'P',
#  'E',
#  7,
#  5,
#  'G',
#  'L',
#  6,
#  2,
#  'C',
#  'E',
#  6,
#  7,
#  'U',
#  'M',
#  3,
#  8,
#  'O',
#  'C',
#  7,
#  'N',
#  9,
#  10,
#  'B',
#  'Y',
#  6,
#  'W',
#  10,
#  'I',
#  8,
#  10,
#  'A',
#  8,
#  'Q',
#  'A',
#  2,
#  'B',
#  7,
#  'Y',
#  10,
#  'O',
#  10,
#  9,
#  'B',
#  'Y',
#  4,
#  8,
#  'X',
#  5,
#  'A',
#  5,
#  'X',
#  'F',
#  8,
#  9,
#  'K',
#  5,
#  'N',
#  'L',
#  8,
#  3,
#  'U',
#  'P',
#  10,
#  'P',
#  1,
#  'W',
#  2,
#  'V',
#  3,
#  8,
#  'B',
#  'Q',
#  6,
#  'J',
#  4,
#  6,
#  'C',
#  'Z',
#  4,
#  'H',
#  5,
#  6,
#  'V',
#  9,
#  'W',
#  'L',
#  10,
#  8,
#  'I',
#  'D',
#  10,
#  8,
#  'E',
#  'N',
#  4,
#  2,
#  'C',
#  8,
#  'S',
#  9,
#  'B',
#  'I',
#  6,
#  'F',
#  7,
#  10,
#  'L',
#  6,
#  'L',
#  10,
#  'F',
#  'F',
#  2,
#  'E',
#  5,
#  1,
#  'Z',
#  'S',
#  6,
#  'A',
#  8,
#  'A',
#  8,
#  'S',
#  3,
#  'A',
#  1,
#  'A',
#  9,
#  'N',
#  10,
#  10,
#  'X',
#  'Q',
#  9,
#  1,
#  'R',
#  3,
#  'U',
#  7,
#  'U',
#  1,
#  'B',
#  2,
#  'B',
#  7,
#  'B',
#  2,
#  'C',
#  'Z',
#  8,
#  5,
#  'U',
#  6,
#  'Z',
#  'H',
#  6,
#  5,
#  'G',
#  6,
#  'A',
#  6,
#  'Y',
#  'T',
#  8,
#  'F',
#  2,
#  'Q',
#  3,
#  5,
#  'J',
#  'I',
#  4,
#  'H',
#  10,
#  8,
#  'I',
#  'V',
#  8,
#  'N',
#  7,
#  9,
#  'I',
#  'K',
#  7,
#  10,
#  'O',
#  'R',
#  7,
#  2,
#  'D',
#  9,
#  'H',
#  'A',
#  2,
#  7,
#  'R',
#  'A',
#  2,
#  'L',
#  7,
#  'Z',
#  2,
#  'M',
#  10,
#  'C',
#  8,
#  4,
#  'H',
#  'V',
#  7,
#  3,
#  'I',
#  5,
#  'O',
#  1,
#  'V',
#  'D',
#  8,
#  5,
#  'I',
#  'X',
#  8,
#  'K',
#  8,
#  'U',
#  3,
#  'Q',
#  10,
#  'X',
#  4,
#  4,
#  'V',
#  'L',
#  10,
#  6,
#  'C',
#  'K',
#  1,
#  'V',
#  10,
#  'I',
#  6,
#  8,
#  'W',
#  2,
#  'S',
#  'Z',
#  1,
#  5,
#  'Y',
#  'X',
#  2,
#  3,
#  'P',
#  'C',
#  2,
#  'D',
#  10,
#  7,
#  'G',
#  7,
#  'E',
#  'J',
#  9,
#  4,
#  'N',
#  6,
#  'G',
#  'G',
#  10,
#  9,
#  'L',
#  'N',
#  4,
#  'K',
#  9,
#  'B',
#  7,
#  1,
#  'S',
#  'U',
#  1,
#  7,
#  'U',
#  'Z',
#  10,
#  'K',
#  3,
#  7,
#  'N',
#  'D',
#  9,
#  'B',
#  8,
#  9,
#  'H',
#  2,
#  'V',
#  'R',
#  4,
#  5,
#  'X',
#  'U',
#  1,
#  1,
#  'G',
#  'V',
#  5,
#  'L',
#  7,
#  'D',
#  3,
#  2,
#  'C',
#  3,
#  'W',
#  6,
#  'U',
#  2,
#  'M',
#  'L',
#  9,
#  'H',
#  2,
#  2,
#  'K',
#  6,
#  'S',
#  'K',
#  1,
#  3,
#  'J',
#  'T',
#  1,
#  8,
#  'U',
#  'E',
#  7,
#  'X',
#  8,
#  8,
#  'C',
#  3,
#  'L',
#  3,
#  'R',
#  'R',
#  8,
#  'L',
#  5,
#  'R',
#  9,
#  1,
#  'T',
#  1,
#  'T',
#  3,
#  'T',
#  'G',
#  6,
#  9,
#  'N',
#  'T',
#  5,
#  'O',
#  6,
#  'H',
#  7,
#  'Q',
#  5,
#  2,
#  'M',
#  'M',
#  7,
#  'I',
#  8,
#  10,
#  'F',
#  7,
#  'H',
#  2,
#  'D',
#  1,
#  'W',
#  'K',
#  8,
#  'H',
#  2,
#  'Z',
#  10,
#  'S',
#  4,
#  1,
#  'G',
#  'U',
#  9,
#  3,
#  'D',
#  'O',
#  1,
#  'E',
#  9,
#  3,
#  'Q',
#  'G',
#  5,
#  'Z',
#  7]

# %% [markdown]
# # Watson data

# %% [markdown]
# Generate the data and write it to a file

# %%
import random
import string

def generate_watson_test_data(num_tuples=10, tuple_length=4):
    data = []
    for _ in range(num_tuples):
        inner_tuple = tuple(
            (
                random.choice(string.ascii_uppercase), random.randint(1, 10)) if random.choice([True, False]
            ) 
            else (
                    random.randint(1, 10), random.choice(string.ascii_uppercase)
                )
            for _ in range(tuple_length)
        )
        data.append(inner_tuple)
    return data

# Generate sample data
watson_test_data = generate_watson_test_data(108, 4)

with open('watson_data.py', 'w') as f:
    f.write(f'watson_test_data')

# %%
import watson_data as wd 

# hvor mange sæt kort er der i filen?
len(wd.watson_data)
# Out:
# 108

# %%
wd.watson_data
# Out:
# [((7, 'D'), (1, 'O'), (8, 'Z'), (8, 'S')),
#  (('W', 7), ('F', 5), ('X', 7), ('O', 3)),
#  ((1, 'V'), ('P', 7), ('Q', 7), (3, 'E')),
#  ((8, 'S'), (10, 'P'), ('T', 2), ('K', 6)),
#  (('N', 5), (8, 'D'), ('Y', 7), (3, 'K')),
#  (('G', 3), (5, 'P'), ('A', 5), ('J', 9)),
#  ((2, 'C'), (3, 'R'), (2, 'V'), (2, 'O')),
#  ((10, 'P'), (9, 'B'), ('W', 4), ('G', 5)),
#  ((3, 'C'), (7, 'O'), (9, 'L'), (2, 'W')),
#  (('J', 2), ('S', 4), ('R', 6), (2, 'Y')),
#  (('M', 5), ('W', 6), (4, 'V'), (5, 'S')),
#  (('K', 7), (4, 'B'), (1, 'H'), ('Q', 7)),
#  (('Z', 2), (4, 'U'), ('P', 6), ('K', 7)),
#  ((10, 'T'), (5, 'B'), (3, 'A'), ('A', 3)),
#  ((3, 'Y'), ('G', 3), ('I', 6), (4, 'R')),
#  (('F', 8), ('I', 7), ('T', 3), ('M', 10)),
#  ((10, 'C'), ('X', 2), (1, 'M'), (9, 'V')),
#  (('T', 1), ('D', 8), (4, 'T'), (4, 'J')),
#  (('C', 7), ('J', 1), ('R', 7), ('A', 8)),
#  ((4, 'R'), (5, 'Z'), ('F', 2), ('T', 1)),
#  (('Z', 1), (4, 'U'), (5, 'V'), (9, 'L')),
#  ((4, 'T'), ('Z', 9), ('B', 8), (9, 'I')),
#  ((2, 'I'), (1, 'U'), ('C', 4), (7, 'D')),
#  ((3, 'H'), (7, 'I'), (10, 'N'), ('V', 9)),
#  ((9, 'O'), (1, 'L'), ('D', 8), (5, 'H')),
#  ((7, 'F'), (8, 'W'), ('R', 3), ('Q', 5)),
#  (('E', 1), ('T', 4), ('I', 10), (6, 'V')),
#  ((4, 'T'), ('O', 5), ('R', 2), (5, 'M')),
#  ((10, 'Y'), (3, 'I'), (3, 'A'), (3, 'T')),
#  ((3, 'H'), (6, 'J'), ('T', 8), ('L', 9)),
#  ((8, 'W'), (5, 'Z'), ('S', 4), ('I', 8)),
#  ((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B')),
#  (('Z', 8), ('Y', 2), (8, 'G'), ('J', 4)),
#  (('N', 10), (2, 'R'), ('Q', 4), (3, 'S')),
#  (('T', 10), (9, 'K'), (8, 'X'), ('V', 6)),
#  ((5, 'D'), (10, 'B'), (7, 'G'), (5, 'E')),
#  (('U', 10), ('Z', 8), (5, 'K'), ('Y', 4)),
#  (('Z', 10), ('A', 4), (3, 'T'), ('Y', 3)),
#  ((6, 'T'), ('U', 10), (10, 'A'), ('X', 3)),
#  ((2, 'S'), ('Q', 3), (1, 'F'), ('E', 10)),
#  (('R', 1), (1, 'S'), (2, 'O'), ('U', 5)),
#  ((9, 'J'), ('V', 4), (10, 'J'), (4, 'A')),
#  ((9, 'J'), ('C', 8), (5, 'B'), ('C', 1)),
#  ((7, 'I'), ('G', 5), (5, 'O'), (6, 'L')),
#  (('Z', 5), (7, 'P'), (9, 'B'), ('I', 5)),
#  ((9, 'E'), ('W', 10), ('J', 5), (3, 'Z')),
#  (('S', 9), ('G', 4), ('E', 4), ('O', 9)),
#  ((7, 'Z'), ('X', 5), (9, 'O'), ('L', 1)),
#  ((10, 'D'), ('L', 2), ('M', 1), (3, 'U')),
#  (('S', 1), ('K', 3), (5, 'K'), (7, 'Y')),
#  ((8, 'K'), (3, 'F'), (3, 'U'), ('N', 2)),
#  ((8, 'P'), ('S', 1), ('R', 1), (10, 'Y')),
#  (('P', 2), (4, 'F'), (6, 'T'), ('B', 10)),
#  (('C', 6), (3, 'K'), ('K', 7), ('L', 4)),
#  ((7, 'C'), (7, 'D'), ('I', 5), ('W', 3)),
#  ((8, 'O'), (3, 'N'), ('J', 1), ('N', 1)),
#  (('L', 9), ('E', 5), (7, 'S'), (3, 'F')),
#  (('S', 4), (1, 'U'), (3, 'Y'), ('P', 6)),
#  ((5, 'N'), (7, 'D'), ('Q', 6), ('F', 6)),
#  (('T', 2), ('D', 7), ('C', 9), ('F', 10)),
#  ((6, 'H'), ('Z', 6), (7, 'A'), (8, 'G')),
#  (('C', 3), (3, 'X'), (5, 'T'), (7, 'O')),
#  (('M', 3), (10, 'D'), ('A', 5), (9, 'P')),
#  ((6, 'T'), ('X', 1), ('L', 9), (5, 'H')),
#  ((3, 'D'), ('A', 5), (6, 'N'), ('C', 7)),
#  ((6, 'F'), (9, 'Y'), (3, 'M'), ('D', 3)),
#  ((7, 'B'), ('R', 6), ('J', 6), ('A', 2)),
#  ((9, 'A'), (6, 'P'), ('T', 3), (3, 'C')),
#  ((6, 'M'), ('Q', 1), (1, 'W'), ('J', 3)),
#  ((5, 'D'), (7, 'I'), (1, 'V'), ('G', 7)),
#  ((7, 'G'), ('M', 2), ('I', 7), (3, 'P')),
#  (('X', 4), (5, 'G'), ('R', 5), (3, 'T')),
#  ((2, 'M'), ('G', 10), ('Z', 4), (4, 'K')),
#  (('A', 8), (8, 'W'), (1, 'Z'), (5, 'E')),
#  ((2, 'O'), (5, 'D'), ('I', 8), (2, 'O')),
#  ((3, 'X'), ('P', 5), ('D', 10), (7, 'V')),
#  ((9, 'H'), (4, 'S'), ('X', 4), ('K', 5)),
#  ((8, 'D'), ('D', 3), ('S', 8), (1, 'G')),
#  ((10, 'Y'), (4, 'E'), ('Y', 6), (9, 'H')),
#  ((3, 'U'), ('U', 2), (10, 'O'), ('L', 7)),
#  (('H', 5), (1, 'H'), (5, 'X'), ('Y', 2)),
#  (('C', 7), (10, 'U'), ('J', 3), ('K', 3)),
#  (('T', 3), (10, 'K'), (9, 'E'), ('E', 3)),
#  (('S', 6), (2, 'M'), (9, 'X'), ('Z', 1)),
#  (('R', 2), (9, 'D'), (2, 'F'), ('T', 5)),
#  ((10, 'T'), (3, 'I'), (3, 'S'), ('W', 3)),
#  (('I', 4), (8, 'L'), ('S', 2), ('X', 10)),
#  ((3, 'X'), ('U', 8), (10, 'L'), ('W', 6)),
#  (('X', 3), ('Y', 7), (3, 'F'), (3, 'D')),
#  (('E', 3), (5, 'T'), ('R', 9), (4, 'V')),
#  ((2, 'U'), ('V', 5), ('U', 4), (5, 'J')),
#  ((5, 'F'), ('M', 5), ('Z', 9), ('A', 10)),
#  ((2, 'G'), (1, 'B'), ('L', 1), ('Z', 6)),
#  (('L', 9), (8, 'B'), ('T', 10), ('A', 9)),
#  ((7, 'Z'), (2, 'P'), ('C', 5), ('S', 7)),
#  ((6, 'W'), ('E', 2), ('F', 1), ('D', 5)),
#  (('P', 5), (8, 'S'), (8, 'V'), ('P', 10)),
#  ((5, 'N'), ('X', 5), (8, 'E'), (9, 'B')),
#  (('E', 1), (4, 'A'), (10, 'L'), (9, 'V')),
#  (('Z', 7), (9, 'H'), ('W', 7), (6, 'F')),
#  ((8, 'P'), ('A', 4), ('L', 1), ('T', 4)),
#  ((8, 'O'), ('W', 5), ('O', 2), (9, 'W')),
#  (('R', 4), ('Q', 7), (10, 'J'), ('S', 4)),
#  (('E', 4), ('K', 4), (9, 'F'), ('R', 1)),
#  ((9, 'I'), ('Y', 1), (5, 'R'), ('C', 1)),
#  ((2, 'P'), (10, 'O'), ('X', 8), ('U', 1)),
#  ((10, 'F'), ('D', 10), (8, 'K'), ('X', 8)),
#  ((8, 'Z'), ('O', 7), (7, 'R'), (6, 'B'))]

# %%
# I hvor mange af sættene der er brug for at vende et kort?
res = []
for i in wd.watson_data:
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            res.append(j)
            break
        
len(res), res
# Out:
# (95,
#  [(7, 'D'),
#   ('O', 3),
#   (1, 'V'),
#   (3, 'K'),
#   (5, 'P'),
#   (3, 'R'),
#   (9, 'B'),
#   (3, 'C'),
#   (5, 'S'),
#   (1, 'H'),
#   (5, 'B'),
#   (3, 'Y'),
#   ('I', 7),
#   (1, 'M'),
#   ('A', 8),
#   (5, 'Z'),
#   (5, 'V'),
#   (9, 'I'),
#   (1, 'U'),
#   (3, 'H'),
#   (9, 'O'),
#   (7, 'F'),
#   ('E', 1),
#   ('O', 5),
#   (3, 'I'),
#   (3, 'H'),
#   (5, 'Z'),
#   (3, 'M'),
#   (3, 'S'),
#   (9, 'K'),
#   (5, 'D'),
#   ('U', 10),
#   ('A', 4),
#   ('U', 10),
#   (1, 'F'),
#   (1, 'S'),
#   (9, 'J'),
#   (9, 'J'),
#   (7, 'I'),
#   (7, 'P'),
#   (9, 'E'),
#   ('E', 4),
#   (7, 'Z'),
#   (3, 'U'),
#   (5, 'K'),
#   (3, 'F'),
#   (3, 'K'),
#   (7, 'C'),
#   (3, 'N'),
#   ('E', 5),
#   (1, 'U'),
#   (5, 'N'),
#   (7, 'A'),
#   (3, 'X'),
#   ('A', 5),
#   (5, 'H'),
#   (3, 'D'),
#   (9, 'Y'),
#   (7, 'B'),
#   (9, 'A'),
#   (1, 'W'),
#   (5, 'D'),
#   (7, 'G'),
#   (5, 'G'),
#   ('A', 8),
#   (5, 'D'),
#   (3, 'X'),
#   (9, 'H'),
#   (1, 'G'),
#   (9, 'H'),
#   (3, 'U'),
#   (1, 'H'),
#   (9, 'E'),
#   (9, 'X'),
#   (9, 'D'),
#   (3, 'I'),
#   ('I', 4),
#   (3, 'X'),
#   (3, 'F'),
#   ('E', 3),
#   ('U', 4),
#   (5, 'F'),
#   (1, 'B'),
#   ('A', 9),
#   (7, 'Z'),
#   ('E', 2),
#   (5, 'N'),
#   ('E', 1),
#   (9, 'H'),
#   ('A', 4),
#   ('O', 2),
#   ('E', 4),
#   (9, 'I'),
#   ('U', 1),
#   ('O', 7)])

# %%
# I hvor man af sættene der er brug for at vende 2 kort?
res = []
for i in wd.watson_data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 2:
                res.append('x')
len(res), res

#['x' for i in wd.watson_data for j in i if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2)]
# Out:
# (60,
#  ['x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x'])

# %%
# I hvor man af sættene der er brug for at vende 3 kort?
res = []
for i in wd.watson_data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 3:
                res.append(i)
len(res), res
# Out:
# (13,
#  [((3, 'C'), (7, 'O'), (9, 'L'), (2, 'W')),
#   ((10, 'T'), (5, 'B'), (3, 'A'), ('A', 3)),
#   ((9, 'O'), (1, 'L'), ('D', 8), (5, 'H')),
#   ((10, 'Y'), (3, 'I'), (3, 'A'), (3, 'T')),
#   ((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B')),
#   ((5, 'D'), (10, 'B'), (7, 'G'), (5, 'E')),
#   (('Z', 5), (7, 'P'), (9, 'B'), ('I', 5)),
#   ((7, 'C'), (7, 'D'), ('I', 5), ('W', 3)),
#   (('L', 9), ('E', 5), (7, 'S'), (3, 'F')),
#   (('C', 3), (3, 'X'), (5, 'T'), (7, 'O')),
#   ((5, 'D'), (7, 'I'), (1, 'V'), ('G', 7)),
#   ((7, 'G'), ('M', 2), ('I', 7), (3, 'P')),
#   (('A', 8), (8, 'W'), (1, 'Z'), (5, 'E'))])

# %%
# I hvor man af sættene der er brug for at vende 4 kort?
res = []
for i in wd.watson_data:
    count = 0
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] or j[0] in range(1,10,2):
            count += 1
            if count == 4:
                res.append(i)
len(res), res
# Out:
# (1, [((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B'))])

# %%
# Hvor mange set vil fejle testen?
res = []
for i in wd.watson_data:
    for j in i:
        if j[0] in ['A', 'E', 'I', 'O', 'U'] and j[1] not in [2,4,6,8] or j[0] in range(1,10,2) and j[1] in ['A', 'E', 'I', 'O', 'U']: 
            res.append(j)
len(res), res
# Out:
# (4, [(7, 'U'), (9, 'I'), (5, 'U'), (1, 'E')])

# %%
import requests

res = requests.get('https://raw.githubusercontent.com/python-elective-kea/IntroPythonSpring2025/refs/heads/prep/materialer/ses8/watson_data.py')
data = res.text
data
# Out:
# "watson_data = [((7, 'D'), (1, 'O'), (8, 'Z'), (8, 'S')), (('W', 7), ('F', 5), ('X', 7), ('O', 3)), ((1, 'V'), ('P', 7), ('Q', 7), (3, 'E')), ((8, 'S'), (10, 'P'), ('T', 2), ('K', 6)), (('N', 5), (8, 'D'), ('Y', 7), (3, 'K')), (('G', 3), (5, 'P'), ('A', 5), ('J', 9)), ((2, 'C'), (3, 'R'), (2, 'V'), (2, 'O')), ((10, 'P'), (9, 'B'), ('W', 4), ('G', 5)), ((3, 'C'), (7, 'O'), (9, 'L'), (2, 'W')), (('J', 2), ('S', 4), ('R', 6), (2, 'Y')), (('M', 5), ('W', 6), (4, 'V'), (5, 'S')), (('K', 7), (4, 'B'), (1, 'H'), ('Q', 7)), (('Z', 2), (4, 'U'), ('P', 6), ('K', 7)), ((10, 'T'), (5, 'B'), (3, 'A'), ('A', 3)), ((3, 'Y'), ('G', 3), ('I', 6), (4, 'R')), (('F', 8), ('I', 7), ('T', 3), ('M', 10)), ((10, 'C'), ('X', 2), (1, 'M'), (9, 'V')), (('T', 1), ('D', 8), (4, 'T'), (4, 'J')), (('C', 7), ('J', 1), ('R', 7), ('A', 8)), ((4, 'R'), (5, 'Z'), ('F', 2), ('T', 1)), (('Z', 1), (4, 'U'), (5, 'V'), (9, 'L')), ((4, 'T'), ('Z', 9), ('B', 8), (9, 'I')), ((2, 'I'), (1, 'U'), ('C', 4), (7, 'D')), ((3, 'H'), (7, 'I'), (10, 'N'), ('V', 9)), ((9, 'O'), (1, 'L'), ('D', 8), (5, 'H')), ((7, 'F'), (8, 'W'), ('R', 3), ('Q', 5)), (('E', 1), ('T', 4), ('I', 10), (6, 'V')), ((4, 'T'), ('O', 5), ('R', 2), (5, 'M')), ((10, 'Y'), (3, 'I'), (3, 'A'), (3, 'T')), ((3, 'H'), (6, 'J'), ('T', 8), ('L', 9)), ((8, 'W'), (5, 'Z'), ('S', 4), ('I', 8)), ((3, 'M'), (7, 'Q'), ('I', 7), (9, 'B')), (('Z', 8), ('Y', 2), (8, 'G'), ('J', 4)), (('N', 10), (2, 'R'), ('Q', 4), (3, 'S')), (('T', 10), (9, 'K'), (8, 'X'), ('V', 6)), ((5, 'D'), (10, 'B'), (7, 'G'), (5, 'E')), (('U', 10), ('Z', 8), (5, 'K'), ('Y', 4)), (('Z', 10), ('A', 4), (3, 'T'), ('Y', 3)), ((6, 'T'), ('U', 10), (10, 'A'), ('X', 3)), ((2, 'S'), ('Q', 3), (1, 'F'), ('E', 10)), (('R', 1), (1, 'S'), (2, 'O'), ('U', 5)), ((9, 'J'), ('V', 4), (10, 'J'), (4, 'A')), ((9, 'J'), ('C', 8), (5, 'B'), ('C', 1)), ((7, 'I'), ('G', 5), (5, 'O'), (6, 'L')), (('Z', 5), (7, 'P'), (9, 'B'), ('I', 5)), ((9, 'E'), ('W', 10), ('J', 5), (3, 'Z')), (('S', 9), ('G', 4), ('E', 4), ('O', 9)), ((7, 'Z'), ('X', 5), (9, 'O'), ('L', 1)), ((10, 'D'), ('L', 2), ('M', 1), (3, 'U')), (('S', 1), ('K', 3), (5, 'K'), (7, 'Y')), ((8, 'K'), (3, 'F'), (3, 'U'), ('N', 2)), ((8, 'P'), ('S', 1), ('R', 1), (10, 'Y')), (('P', 2), (4, 'F'), (6, 'T'), ('B', 10)), (('C', 6), (3, 'K'), ('K', 7), ('L', 4)), ((7, 'C'), (7, 'D'), ('I', 5), ('W', 3)), ((8, 'O'), (3, 'N'), ('J', 1), ('N', 1)), (('L', 9), ('E', 5), (7, 'S'), (3, 'F')), (('S', 4), (1, 'U'), (3, 'Y'), ('P', 6)), ((5, 'N'), (7, 'D'), ('Q', 6), ('F', 6)), (('T', 2), ('D', 7), ('C', 9), ('F', 10)), ((6, 'H'), ('Z', 6), (7, 'A'), (8, 'G')), (('C', 3), (3, 'X'), (5, 'T'), (7, 'O')), (('M', 3), (10, 'D'), ('A', 5), (9, 'P')), ((6, 'T'), ('X', 1), ('L', 9), (5, 'H')), ((3, 'D'), ('A', 5), (6, 'N'), ('C', 7)), ((6, 'F'), (9, 'Y'), (3, 'M'), ('D', 3)), ((7, 'B'), ('R', 6), ('J', 6), ('A', 2)), ((9, 'A'), (6, 'P'), ('T', 3), (3, 'C')), ((6, 'M'), ('Q', 1), (1, 'W'), ('J', 3)), ((5, 'D'), (7, 'I'), (1, 'V'), ('G', 7)), ((7, 'G'), ('M', 2), ('I', 7), (3, 'P')), (('X', 4), (5, 'G'), ('R', 5), (3, 'T')), ((2, 'M'), ('G', 10), ('Z', 4), (4, 'K')), (('A', 8), (8, 'W'), (1, 'Z'), (5, 'E')), ((2, 'O'), (5, 'D'), ('I', 8), (2, 'O')), ((3, 'X'), ('P', 5), ('D', 10), (7, 'V')), ((9, 'H'), (4, 'S'), ('X', 4), ('K', 5)), ((8, 'D'), ('D', 3), ('S', 8), (1, 'G')), ((10, 'Y'), (4, 'E'), ('Y', 6), (9, 'H')), ((3, 'U'), ('U', 2), (10, 'O'), ('L', 7)), (('H', 5), (1, 'H'), (5, 'X'), ('Y', 2)), (('C', 7), (10, 'U'), ('J', 3), ('K', 3)), (('T', 3), (10, 'K'), (9, 'E'), ('E', 3)), (('S', 6), (2, 'M'), (9, 'X'), ('Z', 1)), (('R', 2), (9, 'D'), (2, 'F'), ('T', 5)), ((10, 'T'), (3, 'I'), (3, 'S'), ('W', 3)), (('I', 4), (8, 'L'), ('S', 2), ('X', 10)), ((3, 'X'), ('U', 8), (10, 'L'), ('W', 6)), (('X', 3), ('Y', 7), (3, 'F'), (3, 'D')), (('E', 3), (5, 'T'), ('R', 9), (4, 'V')), ((2, 'U'), ('V', 5), ('U', 4), (5, 'J')), ((5, 'F'), ('M', 5), ('Z', 9), ('A', 10)), ((2, 'G'), (1, 'B'), ('L', 1), ('Z', 6)), (('L', 9), (8, 'B'), ('T', 10), ('A', 9)), (( ...

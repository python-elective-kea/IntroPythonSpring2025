# %% [markdown]
# # list, tuple, set, dict

# %% [markdown]
# ## List
# * Opret
# * Index
# * Slicing
# * Metoder
#     * dir(list)
# * loop

# %% [markdown]
# ## Tuple
# * Imutable
# * Sequence type
#     * (1, 'Claus', 'Bove', True)
# * loop

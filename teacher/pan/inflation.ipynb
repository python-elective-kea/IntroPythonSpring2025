# %%
import pandas as pd

# %%
df = pd.read_csv('data/OECD.SDD.TPS,DSD_G20_PRICES@DF_G20_PRICES,1.0+all.csv')
df.head()
# Out:
#   STRUCTURE                                    STRUCTURE_ID  \
# 0  DATAFLOW  OECD.SDD.TPS:DSD_G20_PRICES@DF_G20_PRICES(1.0)
# 1  DATAFLOW  OECD.SDD.TPS:DSD_G20_PRICES@DF_G20_PRICES(1.0)
# 2  DATAFLOW  OECD.SDD.TPS:DSD_G20_PRICES@DF_G20_PRICES(1.0)
# 3  DATAFLOW  OECD.SDD.TPS:DSD_G20_PRICES@DF_G20_PRICES(1.0)
# 4  DATAFLOW  OECD.SDD.TPS:DSD_G20_PRICES@DF_G20_PRICES(1.0)
#
#                             STRUCTURE_NAME ACTION REF_AREA  \
# 0  G20 - Consumer price indices, all items      I      CHN
# 1  G20 - Consumer price indices, all items      I      CHN
# 2  G20 - Consumer price indices, all items      I      CHN
# 3  G20 - Consumer price indices, all items      I      CHN
# 4  G20 - Consumer price indices, all items      I      CHN
#
#                  Reference area FREQ Frequency of observation METHODOLOGY  \
# 0  China (People’s Republic of)    Q                Quarterly           N
# 1  China (People’s Republic of)    Q                Quarterly           N
# ...

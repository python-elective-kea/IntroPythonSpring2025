# %% [markdown]
# # Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame([1, 2, 3, 4, 15], [2,3,4,5,10])

# %%
df
# Out:
#      0
# 2    1
# 3    2
# 4    3
# 5    4
# 10  15

# %%
plt.plot(df)
